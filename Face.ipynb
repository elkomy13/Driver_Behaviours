# %%
# !pip install torch

# %%
pwd
# Out:
# 'c:\\Users\\adham.hany\\Desktop\\Computer vision projects\\Driver_behaviours'

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
## 3wzen ngrb yolo5m aw large
model=torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# c:\Users\adham.hany\anaconda3\Lib\site-packages\torch\hub.py:295: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\adham.hany/.cache\torch\hub\master.zip
# YOLOv5  2024-8-12 Python-3.12.4 torch-2.4.0 CPU
#
# ...
# 100%|██████████| 14.1M/14.1M [01:17<00:00, 190kB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# ...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
img = r'C:\Users\adham.hany\Desktop\Computer vision projects\Driver_behaviours\download.jfif'

# %%
result=model(img)
result.print()
# Out:
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 177x188 9 cars, 13 trucks
# Speed: 190.2ms pre-process, 204.5ms inference, 24.0ms NMS per image at shape (1, 3, 608, 640)

# %%
result.render()
# Out:
# [array([[[ 32,  41,  46],
#          [ 26,  33,  39],
#          [ 24,  27,  34],
#          ...,
#          [204, 237,   0],
#          [204, 237,   0],
#          [223, 241, 108]],
#
#         [[  8,  19,  23],
#          [  9,  18,  25],
#          [ 11,  15,  24],
#          ...,
#          [204, 237,   0],
#          [204, 237,   0],
#          [204, 237,   0]],
#
#         [[  0,   3,  11],
#          [  2,  11,  20],
#          [ 20,  24,  35],
#          ...,
#          [204, 237,   0],
#          [204, 237,   0],
#          [204, 237,   0]],
#
#         ...,
#
#         [[ 80,  59,  66],
#          [ 50,  31,  37],
#          [ 98,  81,  87],
#          ...,
#          [131, 140, 155],
#          [134, 143, 158],
#          [136, 145, 160]],
#
#         [[117,  96, 103],
#          [ 79,  60,  66],
#          [ 94,  77,  83],
#          ...,
#          [128, 137, 152],
#          [131, 140, 155],
#          [134, 143, 158]],
#
#         [[ 44,  32,  42],
# ...

# %%
result.show()
# Out:
# <PIL.Image.Image image mode=RGB size=188x177>

# %%
result.xyxy ## coordinates
# Out:
# [tensor([[1.75308e+02, 8.45098e+01, 1.87970e+02, 1.23986e+02, 7.96293e-01, 2.00000e+00],
#          [1.47702e+02, 1.31119e+00, 1.86006e+02, 5.20982e+01, 7.74450e-01, 7.00000e+00],
#          [1.21868e+01, 7.37582e+00, 5.49959e+01, 6.13260e+01, 7.16230e-01, 7.00000e+00],
#          [1.10301e-01, 1.07398e+02, 2.08200e+01, 1.54732e+02, 6.94716e-01, 2.00000e+00],
#          [1.57953e+02, 3.93639e+01, 1.88000e+02, 6.84510e+01, 5.45658e-01, 2.00000e+00],
#          [1.55202e+02, 5.07985e+01, 1.87859e+02, 1.02215e+02, 4.91028e-01, 7.00000e+00],
#          [5.79114e+01, 0.00000e+00, 7.23399e+01, 1.11182e+01, 4.78430e-01, 2.00000e+00],
#          [8.25281e+01, 9.31045e+01, 1.30021e+02, 1.28896e+02, 4.70405e-01, 2.00000e+00],
#          [8.40077e+01, 4.09700e+01, 1.18152e+02, 6.81770e+01, 4.59471e-01, 7.00000e+00],
#          [8.85800e+01, 6.99127e+01, 1.28285e+02, 9.67328e+01, 4.43593e-01, 2.00000e+00],
# ...

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10)== ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...

# %%
import uuid   # Unique identifier 3shan asmi kol sora b esm mo5tlf
import os
import time

# %% [markdown]
# Make the data from my images using the camera

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 20 # number of images for each class , increase the number if i want high acc

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(8)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)

        # delay between every shots(image)
        time.sleep(3)
        
        if cv2.waitKey(10) == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\awake.b5a842b1-5887-11ef-91e6-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842b2-5887-11ef-8635-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842b3-5887-11ef-9e5d-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842b4-5887-11ef-b990-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842b5-5887-11ef-8c4b-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842b6-5887-11ef-aac5-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842b7-5887-11ef-9ddd-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842b8-5887-11ef-a36d-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842b9-5887-11ef-8f46-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842ba-5887-11ef-817e-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842bb-5887-11ef-86f4-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842bc-5887-11ef-9cda-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842bd-5887-11ef-850d-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842be-5887-11ef-8823-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842bf-5887-11ef-b2ba-d8b6a6da1900.jpg
# ...
# data\images\awake.b5a842c0-5887-11ef-ba35-d8b6a6da1900.jpg
# ...

# %% [markdown]
# Next step make annotaions to the images on robflow to divide them into awake and drowsy labels

# %%
# Download weights for training at terminal
# !cd yolov5 
# python train.py --img 320 --batch 16 --epochs 50 --data data.yaml --weights yolov5s.pt --workers 2

# %% [markdown]
# ## After training the model on our data we have exp6 that have our best weights and the last weight at epoch number 50 so we will use to predictions

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp10/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\adham.hany/.cache\torch\hub\master.zip
# YOLOv5  2024-8-12 Python-3.12.4 torch-2.4.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
import os

# %%
img=r'C:\Users\adham.hany\Desktop\Computer vision projects\Driver_behaviours\drowsy-95a7be09-5887-11ef-a5b4-d8b6a6da1900_jpg.rf.e0c50d157f3a54412a15a0bd1c1f5f83.jpg'

# %%
result =model(img)
# Out:
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
result.print()
# Out:
# image 1/1: 640x640 (no detections)
# Speed: 9.0ms pre-process, 178.2ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\adham.hany/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
